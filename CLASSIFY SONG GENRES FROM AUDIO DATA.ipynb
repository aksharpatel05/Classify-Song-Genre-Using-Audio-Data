# %% [markdown]
# **1. Preparing our dataset**

# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv('datasets/fma-rock-vs-hiphop.csv')

# Read in track metrics with the features
echonest_metrics = pd.read_json('datasets/echonest-metrics.json',precise_float=True)

# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = echonest_metrics.merge(tracks[['track_id','genre_top']],on=['track_id'])

# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %% [markdown]
# How our dataset looks :

# %%
echo_tracks.head(5)
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3       134      0.452217      0.513238  0.560410          0.019443  0.096567
# 4       153      0.988306      0.255661  0.979774          0.973006  0.121342
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.124595  100.260  0.621661   Hip-Hop
# 3     0.525519  114.290  0.894072   Hip-Hop
# 4     0.051740   90.241  0.034018      Rock

# %% [markdown]
# **2.Pairwise relationships between continuous variables**

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row0_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col4 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col5 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col6 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col7 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row1_col8 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col3 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col6 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row2_col8 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col0 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col5 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col6 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col7 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row3_col8 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col7 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col6 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row5_col8 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row6_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row6_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row6_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row6_col3 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c38bc2a6_75bc_11ea_9f36_80c16e5be9c3row6_col5 {
#             background-color:  #eae6f1;
#             color:  #000000;

# %% [markdown]
# **3. Normalizing the feature data**

# %%
# Define our features 
features = echo_tracks.drop(["genre_top","track_id"], axis=1)

# Define our labels
labels = echo_tracks["genre_top"]

# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %% [markdown]
# Let’s check how our data frame looks like after standardization

# %%
pd.DataFrame(scaled_train_features).head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.191210  1.304420  0.038316 -1.576494 -0.068755  0.373034  1.153979
# 1 -0.306036  0.501886  0.788176 -1.599809 -0.545463  2.446155  0.007914
# 2 -1.204813  1.684139  0.312852 -1.602876  1.229828  0.135130 -0.777317
# 3 -0.094655  0.417927 -0.265203 -1.553079 -0.607326  2.882707 -0.364657
# 4  1.361706 -0.985896  1.453323  0.979975 -0.442757 -0.364157 -1.072003
#
#           7
# 0  0.462287
# 1 -0.690811
# 2  0.631077
# 3  1.652859
# 4 -1.573102

# %% [markdown]
# **4. Principal Component Analysis on our scaled data**

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline

# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

print("Explained variance ratio : \n{}".format(pca.explained_variance_ratio_))
print("\n")
print("Number of components = {}".format(pca.n_components_))  



# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(8), exp_variance)
ax.set_xlabel('Principal Component ')
# Out:
# Explained variance ratio :
# [0.24297674 0.18044316 0.13650309 0.12994089 0.11056248 0.08302245
#  0.06923783 0.04731336]
#
#
# Number of components = 8
# Text(0.5, 0, 'Principal Component ')

# %% [markdown]
# **5. Further visualization of PCA**

# %%
# Import numpy
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(range(8), cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %% [markdown]
# **6. Train a decision tree to classify the genre**

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Create the classification report for both models
from sklearn.metrics import classification_report

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)
class_rep_tree = classification_report(test_labels, pred_labels_tree)
print("Decision Tree: \n", class_rep_tree)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201

# %% [markdown]
# **7. Compare our decision tree model to a logistic regression**

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %% [markdown]
# **8. Balance our data for greater performance**

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echo_tracks.loc[echo_tracks["genre_top"] == "Hip-Hop"]

# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = echo_tracks.loc[echo_tracks["genre_top"] == "Rock"].sample(len(hop_only), random_state=10)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only])

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# %% [markdown]
# **9. Does balancing our dataset improve model bias?**

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.74      0.73      0.74       230
#         Rock       0.73      0.74      0.73       225
#
#     accuracy                           0.74       455
#    macro avg       0.74      0.74      0.74       455
# weighted avg       0.74      0.74      0.74       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.84      0.80      0.82       230
#         Rock       0.80      0.85      0.83       225
#
#     accuracy                           0.82       455
#    macro avg       0.82      0.82      0.82       455
# weighted avg       0.82      0.82      0.82       455

# %% [markdown]
# **10. Using cross-validation to evaluate our models**

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(n_splits=10, random_state=10,shuffle=True)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score)) 
print("Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7719780219780219
# Logistic Regression: 0.823076923076923
